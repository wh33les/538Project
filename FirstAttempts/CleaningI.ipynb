# %% [markdown]
# # Cleaning I
#
# In order to find a model to use we must clean the data, [`data1`](data/ocean157ksafe.csv) and [`data2`](data/concienciaysustancia10k7safe.csv), and then do some exploration.
#
# Tasks:
# - **Merge the data**
# - **Column descriptions for `data1`**
# - **Translatations for `data2`**
# - **Delete unwanted columns, final cleanup**
#
# In this notebook we do the first two tasks.

# %% [markdown]
# ## Merge the data
#
# Each data set contains the results of one of two surveys conducted.  Respondents were identified using a `hash` identifier.  We wish to merge the two data sets for the respondents who completed both surveys.

# %%
# Import pandas to handle the data
import pandas as pd

# Load the data
data1 = pd.read_csv("data/ocean157ksafe.csv")
data2 = pd.read_csv("data/concienciaysustancia10k7safe.csv")

# Create the merged data frame
master_data = pd.merge(data1,
                       data2, 
                       how='inner',
                       on="hash")
master_data
# Out:
#       0_1  0_2  0_3  0_4  0_5  0_6  0_7  0_8  0_9  0_10  ...  \
# 0       4    5    5    1    5    3    5    1    5     5  ...
# 1       4    3    5    3    4    3    4    4    4     3  ...
# 2       5    5    5    3    3    5    5    1    1     5  ...
# 3       4    4    5    4    4    3    5    3    3     5  ...
# 4       5    3    2    2    5    5    5    4    4     5  ...
# ...   ...  ...  ...  ...  ...  ...  ...  ...  ...   ...  ...
# 7085    5    3    5    2    5    1    5    5    3     5  ...
# 7086    4    5    5    5    2    4    4    5    1     4  ...
# 7087    4    2    3    3    3    4    5    5    3     4  ...
# 7088    2    3    3    3    3    4    5    4    4     4  ...
# 7089    4    2    3    3    4    3    4    5    4     5  ...
#
#       12_usualmente_encuentro_cosas_de_que_reirme  \
# 0                                               6
# 1                                               6
# 2                                               6
# 3                                               4
# 4                                               7
# ...                                           ...
# 7085                                            7
# 7086                                            5
# 7087                                            7
# 7088                                            4
# 7089                                            7
#
#       12_confianza_en_mi_pasar_tiempos_dificiles  \
# 0                                              6
# 1                                              7
# 2                                              3
# 3                                              2
# 4                                              7
# ...                                          ...
# 7085                                           7
# 7086                                           2
# 7087                                           4
# 7088                                           5
# 7089                                           3
#
#       12_en_emergencias_pueden_confiar_en_mi  \
# 0                                          7
# 1                                          7
# 2                                          7
# 3                                          6
# 4                                          7
# ...                                      ...
# 7085                                       7
# 7086                                       7
# 7087                                       7
# 7088                                       7
# 7089                                       7
#
#       12_ver_situacion_varios_puntos_de_vista  12_mi_vida_tiene_sentido  \
# 0                                           7                         7
# 1                                           5                         5
# 2                                           6                         6
# 3                                           6                         3
# 4                                           6                         7
# ...                                       ...                       ...
# 7085                                        5                         6
# 7086                                        6                         1
# 7087                                        7                         3
# 7088                                        7                         6
# 7089                                        5                         4
#
#       12_no_insito_en_cosas_que_no_puedo_hacer_nada  \
# 0                                                 7
# 1                                                 6
# 2                                                 2
# 3                                                 3
# 4                                                 5
# ...                                             ...
# 7085                                              2
# 7086                                              7
# 7087                                              4
# 7088                                              4
# 7089                                              5
#
#       12_encuentro_salida_en_situacion_dificil  \
# 0                                            6
# 1                                            5
# 2                                            6
# 3                                            6
# 4                                            6
# ...                                        ...
# 7085                                         6
# 7086                                         6
# 7087                                         6
# 7088                                         5
# 7089                                         4
#
#       12_tengo_energia_para_lo_que_tengo_que_hacer  \
# 0                                                7
# 1                                                4
# 2                                                4
# 3                                                3
# 4                                                5
# ...                                            ...
# 7085                                             4
# 7086                                             2
# 7087                                             4
# 7088                                             4
# 7089                                             3
#
#       12_siento_comodo_si_hay_gente_a_la_que_no_le_agrado  \
# 0                                                     6
# 1                                                     6
# 2                                                     6
# 3                                                     2
# 4                                                     7
# ...                                                 ...
# 7085                                                  2
# 7086                                                  4
# 7087                                                  4
# 7088                                                  1
# 7089                                                  7
#
#       13_login_disclaimer_fork
# 0                            2
# 1                            2
# 2                            2
# 3                            2
# 4                            2
# ...                        ...
# 7085                         2
# 7086                         2
# 7087                         2
# 7088                         2
# 7089                         2
#
# [7090 rows x 195 columns]

# %% [markdown]
# ## Column descriptions for `data1`
#
# The first data set has a table on [Kaggle](https://www.kaggle.com/datasets/thedevastator/mental-health-in-drug-users-during-covid-19) with the descriptions for the columns, particularly those that are just labelled with numbers.  We wish to replace those column names with the descriptions.  To do this we first need to scrape the data from the table on Kaggle.

# %%
# Import BeautifulSoup to scrape data 
from bs4 import BeautifulSoup

# Import requests to get the html
import requests

# This is the url for the html we want
kaggle_url = "https://www.kaggle.com/datasets/thedevastator/mental-health-in-drug-users-during-covid-19"

# Request the html code and assign it to a variable
kaggle_html = requests.get(kaggle_url)

# Make a BeautifulSoup object
kaggle_soup = BeautifulSoup(kaggle_html.content)

# Show the html
print(kaggle_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    Mental Health in Drug Users During COVID-19 | Kaggle
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="Exploring Personality and Risk Profiles" name="description"/>
#   <meta content="no-cache" name="turbolinks-cache-control"/>
#   <meta content="health,covid19,mental health,research" name="keywords"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0" name="viewport"/>
#   <meta content="#008ABC" name="theme-color"/>
#   <script nonce="kA3urVWPu2Mk+CFGX5NVOw==" type="text/javascript">
#    window["pageRequestStartTime"] = 1678992204117;
#     window["pageRequestEndTime"] = 1678992204223;
#     window["initialPageLoadStartTime"] = new Date().getTime();
#   </script>
#   <link crossorigin="anonymous" href="https://www.google-analytics.com" rel="preconnect"/>
#   <link href="https://stats.g.doubleclick.net" rel="preconnect"/>
#   <link href="https://storage.googleapis.com" rel="preconnect"/>
#   <link href="https://apis.google.com" rel="preconnect"/>
#   <link href="/static/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link crossorigin="use-credentials" href="/static/json/manifest.json" rel="manifest"/>
#   <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
#   <link as="style" href="https://fonts.googleapis.com/icon?family=Google+Material+Icons" rel="preload"/>
#   <link as="style" href="https://fonts.googleapis.com/css?family=Inter:400,400i,500,500i,600,600i,700,700i" rel="preload"/>
#   <link href="https://fonts.googleapis.com/icon?family=Google+Material+Icons" id="async-google-font-1" media="print" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Inter:400,400i,500,500i,600,600i,700,700i" id="async-google-font-2" media="print" rel="stylesheet"/>
#   <script nonce="kA3urVWPu2Mk+CFGX5NVOw==" type="text/javascript">
#    const styleSheetIds = ["async-google-font-1", "async-google-font-2"];
#     styleSheetIds.forEach(function (id) {
#       document.getElementById(id).addEventListener("load", function() {
#         this.media = "all";
#       });
#     });
#   </script>
#   <link href="/datasets/thedevastator/mental-health-in-drug-users-during-covid-19" rel="canonical"/>
#   <link href="/static/assets/vendor.css?v=e4c7092a1deb800ab1ec" rel="stylesheet" type="text/css"/>
#   <link href="/static/assets/app.css?v=cd8745ef71013c8e17ff" rel="stylesheet" type="text/css"/>
#   <script nonce="kA3urVWPu2Mk+CFGX5NVOw==">
#    try{(function(a,s,y,n,c,h,i,d,e){d=s.createElement("style");
#         d.appendChild(s.createTextNode(""));s.head.appendChild(d);d=d.sheet;
#         y=y.map(x => d.insertRule(x + "{ opacity: 0 !important }"));
#         h.start=1*new Date;h.end=i=function(){y.forEach(x => x<d.cssRules.length ? d.deleteRule(x) : {})};
#         (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
#         })(window,document,['.site-header-react__nav'],'dataLayer',2000,{'GTM-52LNT9S':true});}catch(ex){}
#   </script>
#   <script nonce="kA3urVWPu2Mk+CFGX5NVOw==">
#    window.dataLayer = window.dataLayer || [];
#         function gtag() { dataLayer.push(arguments); }
#         gtag('js', new Date());
#         gtag('config', 'UA-12629138-1', {
#             'optimize_id': 'GTM-52LNT9S',
#             'displayFeaturesTask': null,
#             'send_page_view': false,
#             'content_group1': 'Datasets'
#         });
#         gtag('config', 'G-T7QHS60L4Q', {
#             'optimize_id': 'GTM-52LNT9S',
#             'displayFeaturesTask': null,
#             'send_page_view': false,
#             'content_group1': 'Datasets'
#         });
#   </script>
#   <script async="" nonce="kA3urVWPu2Mk+CFGX5NVOw==" src="https://www.googletagmanager.com/gtag/js?id=UA-12629138-1">
#   </script>
#   <meta content="/datasets/thedevastator/mental-health-in-drug-users-during-covid-19" property="og:url"/>
#   <meta content="Mental Health in Drug Users During COVID-19" property="og:title"/>
#   <meta content="Exploring Personality and Risk Profiles" property="og:description"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://storage.googleapis.com/kaggle-datasets-images/2837490/4893227/7870af03f52396386b70c977509d89c2/dataset-card.png?t=2023-01-24-16-43-55" property="og:image"/>
#   <meta content="2665027677054710" property="fb:app_id"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta content="@kaggledatasets" name="twitter:site"/>
#   <meta content="@Kaggle" name="twitter:site"/>
#   <script nonce="kA3urVWPu2Mk+CFGX5NVOw==" type="application/ld+json">
#    {"@context":"http://schema.org/","@type":"Dataset","name":"Mental Health in Drug Users During COVID-19","description":"_____\n# Mental Health in Drug Users During COVID-19\n### Exploring Personality and Risk Profiles\nBy  [[source]](https://zenodo.org/record/4324025#.Y8OqntJBwUE)\n_____\n\n### About this dataset\n&gt; This anonymous online survey dataset explores the mental health outcomes of psychedelic and non-psychedelic drug users during the COVID-19 pandemic. Using psychometric scales to assess personality traits, anxiety, negative and positive affect, well-being and resilience, principal component analysis was applied to ascertain drug use reports from the sample population. Risk profiles including risk taking/avoidance behaviours, risk perception and risk tolerance are analysed to gain a deeper insight into potential correlations with mental health outcomes. Investigating these factors reveals information on how different psychosocial factors may impact on an individual’s wellbeing in times of uncertainty as experienced in this global pandemic\n\n### More Datasets\n&gt; For more datasets, click [here](https://www.kaggle.com/thedevastator/datasets).\n\n### Featured Notebooks\n&gt; - 🚨 **Your notebook can be here!** 🚨! \n\n### How to use the dataset\n&gt; This dataset contains survey responses from psychedelic and non-psychedelic drug users during the COVID-19 pandemic, exploring their mental health outcomes and personality traits. It is intended for researchers to use for studying correlations between drug use and risk profile factors with mental health outcomes in order to better understand the effects of different substances on individuals’ psychological wellbeing during this unprecedented global event.\n&gt; \n&gt; To help you get started working with this dataset, we have provided a description of the data columns below. \n&gt; **0_1:** Age (Numeric) \n&gt; **0_2:** Gender (Categorical) \n&gt; **0_3:** Education Level (Categorical) \n&gt; **0_4:** Employment Status (Categorical) \n&gt; **0_5: Country of Residence (Categorical) \n&gt;  **0_6: Number of Psychedelic Drug Experiences (Numeric) \n&gt;  **0_7 :Number of Non-psychedelic Drug Experiences(Numeric)   [This field is blank if zero]  \n&gt; \n&gt;  ** 0_8 :Personality Traits(Numeric)[ This field is blank if zero]    \n&gt; \n&gt;  ** 0_9 :Anxiety( Numeric )[ This field is blank if zero]   \n&gt; \n&gt;  ** 0 _ 10: Negative Affect( Numeric )[ This field is blank if zero ]    \n&gt; \n&gt;  ** 0 _ 11 : Positive Affect( Numeric )[ This field is blank if zero ]     \n&gt; \n&gt;  ** 0 _ 12 : Well - being( Numeric )[ This field is blankifzero ]     \n&gt; \n&gt;  $$ 0013$$$${\\rm \\ \\ }$$Resilience$${\\rm \\ \\ }$$\\left({\\rm numeric}\\right){\\rm [This~~field~~is~~blankifzero]}$$$$$${15} {16} {17} {18} {19}$$$${\\rm Risk~Tolerance~~~~~Risk~Aversion~~~~~Risk~Taking~~~~~~~~~~~~Risk~Avoidance~~~~Mental}{20}{21}{22}{23}{24}{25{26}}{27 {\\bf Health ~Outcomes}}}    $$\\left({\\rm numeric}\\right)\\mathop {{}}\\limits^{^{\\approx }}_{_. } {\\kern 1pts }                                                             {\\kern 1pts }\\left({{{20}, 21, 22, 23, 24, 26}, 27}\\right)\\cong ({695\n\n### Research Ideas\n&gt; - Metaregression analysis exploring the impact of psychedelic and non-psychedelic drug use on mental health outcomes, such as anxiety and negative affect.\n&gt; - Create machine learning models that can be deployed to assess the potential risk for developing mental health issues based on personality traits, substance use, risk profiles and demographics. \n&gt; - Analyzing trends in psychedelic/non-psychedelic drug usage during the COVID-19 pandemic through a visual dashboard display for policy makers and mental health professionals to better identify at-risk groups of individuals\n\n### Acknowledgements\n&gt; If you use this dataset in your research, please credit the original authors.\n&gt; [Data Source](https://zenodo.org/record/4324025#.Y8OqntJBwUE)\n&gt; \n ...
#   </script>
#   <script nonce="kA3urVWPu2Mk+CFGX5NVOw==">
#    window['useKaggleAnalytics'] = true;
#   </script>
#   <script async="" defer="" id="gapi-target" nonce="kA3urVWPu2Mk+CFGX5NVOw==" src="https://apis.google.com/js/api.js">
#   </script>
#   <script data-turbolinks-track="reload" nonce="kA3urVWPu2Mk+CFGX5NVOw==" src="/static/assets/runtime.js?v=fa7ac81637eae2239462">
#   </script>
#   <script data-turbolinks-track="reload" nonce="kA3urVWPu2Mk+CFGX5NVOw==" src="/static/assets/vendor.js?v=a770e07d34d25c4fbaaa">
#   </script>
#   <script data-turbolinks-track="reload" nonce="kA3urVWPu2Mk+CFGX5NVOw==" src="/static/assets/app.js?v=321afc799039997c94bf">
#   </script>
#   <script nonce="kA3urVWPu2Mk+CFGX5NVOw==" type="text/javascript">
#    window.kaggleStackdriverConfig = {
#         key: 'AIzaSyA4eNqUdRRskJsCZWVz-qL655Xa5JEMreE',
#         projectId: 'kaggle-161607',
#         service: 'web-fe',
#         version: 'ci',
#         userId: '0'
#       }
#   </script>
#  </head>
#  <body data-turbolinks="false">
#   <main>
#    <div id="site-container">
#    </div>
#    <div class="hide" id="site-body">
#     <div data-component-name="DatasetMaterialContainer" style="display: flex; flex-direction: column; flex: 1 0 auto;">
#     </div>
#     <script class="kaggle-component" nonce="kA3urVWPu2Mk+CFGX5NVOw==">
#      var Kaggle=window.Kaggle||{};Kaggle.State=Kaggle.State||[];Kaggle.State.push({"basics":{"datasetId":2837490,"slug":"mental-health-in-drug-users-during-covid-19","title":"Mental Health in Drug Users During COVID-19","description":"_____\n# Mental Health in Drug Users During COVID-19\n### Exploring Personality and Risk Profiles\nBy  [[source]](https://zenodo.org/record/4324025#.Y8OqntJBwUE)\n_____\n\n### About this dataset\n\u0026gt; This anonymous online survey dataset explores the mental health outcomes of psychedelic and non-psychedelic drug users during the COVID-19 pandemic. Using psychometric scales to assess personality traits, anxiety, negative and positive affect, well-being and resilience, principal component analysis was applied to ascertain drug use reports from the sample population. Risk profiles including risk taking/avoidance behaviours, risk perception and risk tolerance are analysed to gain a deeper insight into potential correlations with mental health outcomes. Investigating these factors reveals information on how different psychosocial factors may impact on an individual\u2019s wellbeing in times of uncertainty as experienced in this global pandemic\n\n### More Datasets\n\u0026gt; For more datasets, click [here](https://www.kaggle.com/thedevastator/datasets).\n\n### Featured Notebooks\n\u0026gt; - \uD83D\uDEA8 **Your notebook can be here!** \uD83D\uDEA8! \n\n### How to use the dataset\n\u0026gt; This dataset contains survey responses from psychedelic and non-psychedelic drug users during the COVID-19 pandemic, exploring their mental health outcomes and personality traits. It is intended for researchers to use for studying correlations between drug use and risk profile factors with mental health outcomes in order to better understand the effects of different substances on individuals\u2019 psychological wellbeing during this unprecedented global event.\n\u0026gt; \n\u0026gt; To help you get started working with this dataset, we have provided a description of the data columns below. \n\u0026gt; **0_1:** Age (Numeric) \n\u0026gt; **0_2:** Gender (Categorical) \n\u0026gt; **0_3:** Education Level (Categorical) \n\u0026gt; **0_4:** Employment Status (Categorical) \n\u0026gt; **0_5: Country of Residence (Categorical) \n\u0026gt;  **0_6: Number of Psychedelic Drug Experiences (Numeric) \n\u0026gt;  **0_7 :Number of Non-psychedelic Drug Experiences(Numeric)   [This field is blank if zero]  \n\u0026gt; \n\u0026gt;  ** 0_8 :Personality Traits(Numeric)[ This field is blank if zero]    \n\u0026gt; \n\u0026gt;  ** 0_9 :Anxiety( Numeric )[ This field is blank if zero]   \n\u0026gt; \n\u0026gt;  ** 0 _ 10: Negative Affect( Numeric )[ This field is blank if zero ]    \n\u0026gt; \n\u0026gt;  ** 0 _ 11 : Positive Affect( Numeric )[ This field is blank if zero ]     \n\u0026gt; \n\u0026gt;  ** 0 _ 12 : Well - being( Numeric )[ This field is blankifzero ]     \n\u0026gt; \n\u0026gt;  $$ 0013$$$${\\rm \\ \\ }$$Resilience$${\\rm \\ \\ }$$\\left({\\rm numeric}\\right){\\rm [This~~field~~is~~blankifzero]}$$$$$${15} {16} {17} {18} {19}$$$${\\rm Risk~Tolerance~~~~~Risk~Aversion~~~~~Risk~Taking~~~~~~~~~~~~Risk~Avoidance~~~~Mental}{20}{21}{22}{23}{24}{25{26}}{27 {\\bf Health ~Outcomes}}}    $$\\left({\\rm numeric}\\right)\\mathop {{}}\\limits^{^{\\approx }}_{_. } {\\kern 1pts }                                                             {\\kern 1pts }\\left({{{20}, 21, 22, 23, 24, 26}, 27}\\right)\\cong ({695\n\n### Research Ideas\n\u0026gt; - Metaregression analysis exploring the impact of psychedelic and non-psychedelic drug use on mental health outcomes, such as anxiety and negative affect.\n\u0026gt; - Create machine learning models that can be deployed to assess the potential risk for developing mental health issues based on personality traits, substance use, risk profiles and demographics. \n\u0026gt; - Analyzing trends in psychedelic/non-psychedelic drug usage during the COVID-19 pandemic through a visual dashboard displa ...
#     </script>
#     <script nonce="kA3urVWPu2Mk+CFGX5NVOw==" type="text/x-mathjax-config">
#      MathJax.Hub.Config({
#     "HTML-CSS": {
#     preferredFont: "TeX",
#     availableFonts: ["STIX", "TeX"],
#     linebreaks: {
#     automatic: true
#     },
#     EqnChunk: (MathJax.Hub.Browser.isMobile ? 10 : 50)
#     },
#     tex2jax: {
#     inlineMath: [["\\(", "\\)"], ["\\\\(", "\\\\)"]],
#     displayMath: [["$$", "$$"], ["\\[", "\\]"]],
#     processEscapes: true,
#     ignoreClass: "tex2jax_ignore|dno"
#     },
#     TeX: {
#     noUndefined: {
#     attributes: {
#     mathcolor: "red",
#     mathbackground: "#FFEEEE",
#     mathsize: "90%"
#     }
#     }
#     },
#     Macros: {
#     href: "{}"
#     },
#     skipStartupTypeset: true,
#     messageStyle: "none",
#     extensions: ["Safe.js"],
#     });
#     </script>
#     <script nonce="kA3urVWPu2Mk+CFGX5NVOw==" type="text/javascript">
#      window.addEventListener("DOMContentLoaded", () => {
#     const head = document.getElementsByTagName("head")[0];
#     const useProdHosts = ["www.kaggle.com", "admin.kaggle.com"];
#     const subdomain = useProdHosts.includes(window.location.hostname) ? "www" : "staging";
#
#     const lib = document.createElement("script");
#     lib.type = "text/javascript";
#     lib.src = `https://${subdomain}.kaggleusercontent.com/static/mathjax/2.7.9/MathJax.js?config=TeX-AMS-MML_HTMLorMML`;
#     head.appendChild(lib);
#   });
#     </script>
#    </div>
#   </main>
#  </body>
# </html>

# %% [markdown]
# The table appears twice, in the head element and in the body element.  It happens to occur in the first `script` element in the body, so we will use that information to extract it.

# %%
# Find the html element that contains the table
kaggle_table = kaggle_soup.body.find('script').text # Turns the html into a string
kaggle_table
# Out:
# 'var Kaggle=window.Kaggle||{};Kaggle.State=Kaggle.State||[];Kaggle.State.push({"basics":{"datasetId":2837490,"slug":"mental-health-in-drug-users-during-covid-19","title":"Mental Health in Drug Users During COVID-19","description":"_____\\n# Mental Health in Drug Users During COVID-19\\n### Exploring Personality and Risk Profiles\\nBy  [[source]](https://zenodo.org/record/4324025#.Y8OqntJBwUE)\\n_____\\n\\n### About this dataset\\n\\u0026gt; This anonymous online survey dataset explores the mental health outcomes of psychedelic and non-psychedelic drug users during the COVID-19 pandemic. Using psychometric scales to assess personality traits, anxiety, negative and positive affect, well-being and resilience, principal component analysis was applied to ascertain drug use reports from the sample population. Risk profiles including risk taking/avoidance behaviours, risk perception and risk tolerance are analysed to gain a deeper insight into potential correlations with mental health outcomes. Investigating these factors reveals information on how different psychosocial factors may impact on an individual\\u2019s wellbeing in times of uncertainty as experienced in this global pandemic\\n\\n### More Datasets\\n\\u0026gt; For more datasets, click [here](https://www.kaggle.com/thedevastator/datasets).\\n\\n### Featured Notebooks\\n\\u0026gt; - \\uD83D\\uDEA8 **Your notebook can be here!** \\uD83D\\uDEA8! \\n\\n### How to use the dataset\\n\\u0026gt; This dataset contains survey responses from psychedelic and non-psychedelic drug users during the COVID-19 pandemic, exploring their mental health outcomes and personality traits. It is intended for researchers to use for studying correlations between drug use and risk profile factors with mental health outcomes in order to better understand the effects of different substances on individuals\\u2019 psychological wellbeing during this unprecedented global event.\\n\\u0026gt; \\n\\u0026gt; To help you get started working with this dataset, we have provided a description of the data columns below. \\n\\u0026gt; **0_1:** Age (Numeric) \\n\\u0026gt; **0_2:** Gender (Categorical) \\n\\u0026gt; **0_3:** Education Level (Categorical) \\n\\u0026gt; **0_4:** Employment Status (Categorical) \\n\\u0026gt; **0_5: Country of Residence (Categorical) \\n\\u0026gt;  **0_6: Number of Psychedelic Drug Experiences (Numeric) \\n\\u0026gt;  **0_7 :Number of Non-psychedelic Drug Experiences(Numeric)   [This field is blank if zero]  \\n\\u0026gt; \\n\\u0026gt;  ** 0_8 :Personality Traits(Numeric)[ This field is blank if zero]    \\n\\u0026gt; \\n\\u0026gt;  ** 0_9 :Anxiety( Numeric )[ This field is blank if zero]   \\n\\u0026gt; \\n\\u0026gt;  ** 0 _ 10: Negative Affect( Numeric )[ This field is blank if zero ]    \\n\\u0026gt; \\n\\u0026gt;  ** 0 _ 11 : Positive Affect( Numeric )[ This field is blank if zero ]     \\n\\u0026gt; \\n\\u0026gt;  ** 0 _ 12 : Well - being( Numeric )[ This field is blankifzero ]     \\n\\u0026gt; \\n\\u0026gt;  $$ 0013$$$${\\\\rm \\\\ \\\\ }$$Resilience$${\\\\rm \\\\ \\\\ }$$\\\\left({\\\\rm numeric}\\\\right){\\\\rm [This~~field~~is~~blankifzero]}$$$$$${15} {16} {17} {18} {19}$$$${\\\\rm Risk~Tolerance~~~~~Risk~Aversion~~~~~Risk~Taking~~~~~~~~~~~~Risk~Avoidance~~~~Mental}{20}{21}{22}{23}{24}{25{26}}{27 {\\\\bf Health ~Outcomes}}}    $$\\\\left({\\\\rm numeric}\\\\right)\\\\mathop {{}}\\\\limits^{^{\\\\approx }}_{_. } {\\\\kern 1pts }                                                             {\\\\kern 1pts }\\\\left({{{20}, 21, 22, 23, 24, 26}, 27}\\\\right)\\\\cong ({695\\n\\n### Research Ideas\\n\\u0026gt; - Metaregression analysis exploring the impact of psychedelic and non-psychedelic drug use on mental health outcomes, such as anxiety and negative affect.\\n\\u0026gt; - Create machine learning models that can be deployed to assess the potential risk for developing mental health issues based on personality traits, substance use, risk profiles and demographics. \\n\\u0026gt; - Ana ...

# %% [markdown]
# To further isolate the table from the `script` element, we can use the `split` function to separate each row of the table by the string `|\\n`.  Note that the original html only had one backslash, but when we turned the html into a string an escape character was added.

# %%
# Use "|\\n" to split the html according to the rows of the table
kaggle_strings = kaggle_table.split("|\\n")
kaggle_strings
# Out:
# ['var Kaggle=window.Kaggle||{};Kaggle.State=Kaggle.State||[];Kaggle.State.push({"basics":{"datasetId":2837490,"slug":"mental-health-in-drug-users-during-covid-19","title":"Mental Health in Drug Users During COVID-19","description":"_____\\n# Mental Health in Drug Users During COVID-19\\n### Exploring Personality and Risk Profiles\\nBy  [[source]](https://zenodo.org/record/4324025#.Y8OqntJBwUE)\\n_____\\n\\n### About this dataset\\n\\u0026gt; This anonymous online survey dataset explores the mental health outcomes of psychedelic and non-psychedelic drug users during the COVID-19 pandemic. Using psychometric scales to assess personality traits, anxiety, negative and positive affect, well-being and resilience, principal component analysis was applied to ascertain drug use reports from the sample population. Risk profiles including risk taking/avoidance behaviours, risk perception and risk tolerance are analysed to gain a deeper insight into potential correlations with mental health outcomes. Investigating these factors reveals information on how different psychosocial factors may impact on an individual\\u2019s wellbeing in times of uncertainty as experienced in this global pandemic\\n\\n### More Datasets\\n\\u0026gt; For more datasets, click [here](https://www.kaggle.com/thedevastator/datasets).\\n\\n### Featured Notebooks\\n\\u0026gt; - \\uD83D\\uDEA8 **Your notebook can be here!** \\uD83D\\uDEA8! \\n\\n### How to use the dataset\\n\\u0026gt; This dataset contains survey responses from psychedelic and non-psychedelic drug users during the COVID-19 pandemic, exploring their mental health outcomes and personality traits. It is intended for researchers to use for studying correlations between drug use and risk profile factors with mental health outcomes in order to better understand the effects of different substances on individuals\\u2019 psychological wellbeing during this unprecedented global event.\\n\\u0026gt; \\n\\u0026gt; To help you get started working with this dataset, we have provided a description of the data columns below. \\n\\u0026gt; **0_1:** Age (Numeric) \\n\\u0026gt; **0_2:** Gender (Categorical) \\n\\u0026gt; **0_3:** Education Level (Categorical) \\n\\u0026gt; **0_4:** Employment Status (Categorical) \\n\\u0026gt; **0_5: Country of Residence (Categorical) \\n\\u0026gt;  **0_6: Number of Psychedelic Drug Experiences (Numeric) \\n\\u0026gt;  **0_7 :Number of Non-psychedelic Drug Experiences(Numeric)   [This field is blank if zero]  \\n\\u0026gt; \\n\\u0026gt;  ** 0_8 :Personality Traits(Numeric)[ This field is blank if zero]    \\n\\u0026gt; \\n\\u0026gt;  ** 0_9 :Anxiety( Numeric )[ This field is blank if zero]   \\n\\u0026gt; \\n\\u0026gt;  ** 0 _ 10: Negative Affect( Numeric )[ This field is blank if zero ]    \\n\\u0026gt; \\n\\u0026gt;  ** 0 _ 11 : Positive Affect( Numeric )[ This field is blank if zero ]     \\n\\u0026gt; \\n\\u0026gt;  ** 0 _ 12 : Well - being( Numeric )[ This field is blankifzero ]     \\n\\u0026gt; \\n\\u0026gt;  $$ 0013$$$${\\\\rm \\\\ \\\\ }$$Resilience$${\\\\rm \\\\ \\\\ }$$\\\\left({\\\\rm numeric}\\\\right){\\\\rm [This~~field~~is~~blankifzero]}$$$$$${15} {16} {17} {18} {19}$$$${\\\\rm Risk~Tolerance~~~~~Risk~Aversion~~~~~Risk~Taking~~~~~~~~~~~~Risk~Avoidance~~~~Mental}{20}{21}{22}{23}{24}{25{26}}{27 {\\\\bf Health ~Outcomes}}}    $$\\\\left({\\\\rm numeric}\\\\right)\\\\mathop {{}}\\\\limits^{^{\\\\approx }}_{_. } {\\\\kern 1pts }                                                             {\\\\kern 1pts }\\\\left({{{20}, 21, 22, 23, 24, 26}, 27}\\\\right)\\\\cong ({695\\n\\n### Research Ideas\\n\\u0026gt; - Metaregression analysis exploring the impact of psychedelic and non-psychedelic drug use on mental health outcomes, such as anxiety and negative affect.\\n\\u0026gt; - Create machine learning models that can be deployed to assess the potential risk for developing mental health issues based on personality traits, substance use, risk profiles and demographics. \\n\\u0026gt; - An ...
#  '|:----------------------------------|:----------------------------------------------------------------------------------------------',
#  '| **0_1**                           | Age of the respondent. (Numeric)                                                              ',
#  '| **0_2**                           | Gender of the respondent. (Categorical)                                                       ',
#  '| **0_3**                           | Country of residence of the respondent. (Categorical)                                         ',
#  '| **0_4**                           | Number of times the respondent has used psychedelics. (Numeric)                               ',
#  '| **0_5**                           | Number of times the respondent has used other psychoactive drugs. (Numeric)                   ',
#  '| **0_6**                           | Number of times the respondent has used psychedelics in the past year. (Numeric)              ',
#  '| **0_7**                           | Number of times the respondent has used other psychoactive drugs in the past year. (Numeric)  ',
#  '| **0_8**                           | Number of times the respondent has used psychedelics in the past month. (Numeric)             ',
#  '| **0_9**                           | Number of times the respondent has used other psychoactive drugs in the past month. (Numeric) ',
#  '| **0_10**                          | Number of times the respondent has used psychedelics in the past week. (Numeric)              ',
#  '| **0_11**                          | Number of times the respondent has used other psychoactive drugs in the past week. (Numeric)  ',
#  '| **0_12**                          | Number of times the respondent has used psychedelics in the past day. (Numeric)               ',
#  '| **0_13**                          | Number of times the respondent has used other psychoactive drugs in the past day. (Numeric)   ',
#  '| **0_14**                          | The respondent\\u0027s level of anxiety. (Numeric)                                                  ',
#  '| **0_15**                          | The respondent\\u0027s level of resilience. (Numeric)                                               ',
#  '| **0_16**                          | The respondent\\u0027s level of overall wellbeing. (Numeric)                                        ',
#  '| **0_17**                          | The respondent\\u0027s level of openness to experience. (Numeric)                                   ',
#  '| **0_18**                          | The respondent\\u0027s level of conscientiousness. (Numeric)                                        ',
#  '| **0_19**                          | The respondent\\u0027s level of extraversion. (Numeric)                                             ',
#  '| **0_20**                          | The respondent\\u0027s level of agreeableness. (Numeric)                                            ',
#  '| **0_41**                          | Number of times the respondent has used psychedelics in the past year. (Numeric)              ',
#  '| **0_42**                          | Number of times the respondent has used other psychoactive drugs in the past year. (Numeric)  ',
#  '| **0_43**                          | Number of times the respondent has used psychedelics in the past month. (Numeric)             ',
#  '| **0_44**                          | Number of times the respondent has used other psychoactive drugs in the past month. (Numeric) ',
#  '| **1_extraversion**                | The respondent\\u0027s level of extraversion. (Numeric)                                             ',
#  '| **1_agreeableness**               | The respondent\\u0027s level of agreeableness. (Numeric)                                            ',
#  '| **1_conscientiousness**           | The respondent\\u0027s level of conscientiousness. (Numeric)                                        ',
#  '| **1_neuroticism**                 | The respondent\\u0027s level of neuroticism. (Numeric)                                              ',
#  '| **1_openness**                    | The respondent\\u0027s level of openness to experience. (Numeric)                                   ',
#  '| **1_percentil_extraversion**      | The respondent\\u0027s percentile of extraversion. (Numeric)                                        ',
#  '| **1_percentil_agreeableness**     | The respondent\\u0027s percentile of agreeableness. (Numeric)                                       ',
#  '| **1_percentil_conscientiousness** | The respondent\\u0027s percentile of conscientiousness. (Numeric)                                   ',
#  '| **1_percentil_neuroticism**       | The respondent\\u0027s percentile of neuroticism. (Numeric)                                         ',
#  '| **1_percentil_openness**          | The respondent\\u0027s percentile of openness to experience. (Numeric)                              ',
#  '| **2_edad**                        | Age of the respondent. (Numeric)                                                              ',
#  '| **2_genero**                      | Gender of the respondent. (Categorical)                                                       ',
#  '| **2_pais_actual**                 | Country of residence of the respondent. (Categorical)                                         ',
#  '| **3_timestamp**                   | Timestamp of the survey response. (Numeric)                                                   ',
#  '| **hash**                          | Unique identifier for the respondent. (String)                                                ',
#  '| **0_21**                          | The respondent\\u0027s level of risk aversion. (Numeric)                                            ',
#  '| **0_22**                          | The respondent\\u0027s level of risk taking. (Numeric)                                              ',
#  '| **0_23**                          | The respondent\\u0027s level of impulsivity                                                         ',
#  '\\n### Acknowledgements\\n\\u0026gt; If you use this dataset in your research, please credit the original authors.\\n\\u0026gt; If you use this dataset in your research, please credit [](https://zenodo.org/record/4324025#.Y8OqntJBwUE).\\n\\n","viewCount":4707,"downloadCount":729,"topicCount":1,"owner":{"id":10654180,"imageUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/10654180-kg.png","name":"The Devastator","profileUrl":"/thedevastator","slug":"thedevastator","userTier":"GRANDMASTER"},"license":{"id":1,"name":"CC0: Public Domain","url":"https://creativecommons.org/publicdomain/zero/1.0/"},"overview":"Exploring Personality and Risk Profiles","collaboratorList":{"owner":{"userId":10654180,"profileUrl":"/thedevastator","thumbnailUrl":"https://storage.googleapis.com/kaggle-avatars/thumbnails/10654180-kg.png","name":"The Devastator","slug":"thedevastator","userTier":"GRANDMASTER","type":"OWNER"}},"coverImageUrl":"https://storage.googleapis.com/kaggle-datasets-images/2837490/4893227/7870af03f52396386b70c977509d89c2/dataset-cover.png?t=2023-01-24-16-43-55","data":{"totalSize":8882972,"isFileset":true,"canDownload":true,"firestorePath":"HCgmmYuzxJWQVm3aqaWz/versions/lzqkVm6YdBsonFdSqxZk","downloadUrl":"/datasets/thedevastator/thedevastator/download?datasetVersionNumber=1","versionId":4960528,"id":2875985},"voteCount":29,"downloadUrl":"/datasets/thedevastator/mental-health-in-drug-users-during-covid-19/download?datasetVersionNumber=1","lastUpdateTime":"2023-01-24T16:42:45.717Z","datasetVersionNumber":1,"creatorDisplayName":"The Devastator","cardImageUrl":"https://storage.googleapis.com/kaggle-datasets-images/2837490/4893227/7870af03f52396386b70c977509d89c2/dataset-card.png?t=2023-01-24-16-43-55","categories":{"tags":[{"id":11111,"name":"health","fullPath":"subject \\u003E health and fitness \\u003E health","listingUrl":"/datasets?group=public\\u0026tagids=11111","description":"Consider the health tag your data science gym. Get in there and work out those data science muscles on health analytics. Analyze heart disease until you sweat. Then recover with with a nice candy production dataset.","datasetCount":8190,"competitionCount":5,"notebookCount":7515,"tagUrl":"/tags/health","displayName":"Health"},{"id":16575,"name":"covid19","fullPath":"subject \\u003E health and fitness \\u003E health \\u003E health conditions \\u003E diseases \\u003E covid19","listingUrl":"/datasets?group=public\\u0026tagids=16575","description":"COVID-19 is a disease that is caused by the SARS-CoV-2 virus. In 2020 there was a global COVID-19 pandemic.","datasetCount":1756,"competitionCount":9,"notebookCount":2446,"tagUrl":"/tags/covid19","displayName":"Coronavirus"},{"id":4171,"name":"mental health","fullPath":"subject \\u003E health and fitness \\u003E health \\u003E health conditions \\u003E mental health","listingUrl":"/datasets?group=public\\u0026tagids=4171","description":"Mental health is a level of psychological well-being, or an absence of mental illness.","datasetCount":605,"notebookCount":197,"tagUrl":"/tags/mental-health","displayName":"Mental Health"},{"id":1219,"name":"research","fullPath":"subject \\u003E science and technology \\u003E research","listingUrl":"/datasets?group=public\\u0026tagids=1219","description":"Research is our endeavor to systematically increase our knowledge about the world. Whether it\\u0027s undertaken by greats like Einstein or underpaid graduate students, you\\u0027ll find the fruits of their labor in this tag plus the kernels that make their work reproducible.","datasetCount":519,"competitionCount":7,"notebookCount":282,"tagUrl":"/tags/research","displayName":"Research"}]},"datasetExternalUrl":"https://www.kaggle.com/datasets/thedevastator/mental-health-in-drug-users-during-covid-19","forumId":2872804,"datasetVersionId":4893227,"canCreateTasks":true,"moderationStatus":"PRIVATED_MODERATION_STATUS_NO_ABUSE","lastVersionNumber":1,"diffType":"VERSIONED"}});performance && performance.mark && performance.mark("D ...

# %% [markdown]
# Now we have a list of strings that includes each line of the table, but we don't want the first two strings or the last one, so we can get rid of them.

# %%
# Indices of the unwanted strings
unwanted = [0,1,len(kaggle_strings)-1]

# Delete the unwanted strings
for kaggle_strings_index in sorted(unwanted, 
                                   reverse=True): # It's good practice to delete the highest indices first, so we reverse the order of the indices
    del kaggle_strings[kaggle_strings_index]
kaggle_strings
# Out:
# ['| **0_1**                           | Age of the respondent. (Numeric)                                                              ',
#  '| **0_2**                           | Gender of the respondent. (Categorical)                                                       ',
#  '| **0_3**                           | Country of residence of the respondent. (Categorical)                                         ',
#  '| **0_4**                           | Number of times the respondent has used psychedelics. (Numeric)                               ',
#  '| **0_5**                           | Number of times the respondent has used other psychoactive drugs. (Numeric)                   ',
#  '| **0_6**                           | Number of times the respondent has used psychedelics in the past year. (Numeric)              ',
#  '| **0_7**                           | Number of times the respondent has used other psychoactive drugs in the past year. (Numeric)  ',
#  '| **0_8**                           | Number of times the respondent has used psychedelics in the past month. (Numeric)             ',
#  '| **0_9**                           | Number of times the respondent has used other psychoactive drugs in the past month. (Numeric) ',
#  '| **0_10**                          | Number of times the respondent has used psychedelics in the past week. (Numeric)              ',
#  '| **0_11**                          | Number of times the respondent has used other psychoactive drugs in the past week. (Numeric)  ',
#  '| **0_12**                          | Number of times the respondent has used psychedelics in the past day. (Numeric)               ',
#  '| **0_13**                          | Number of times the respondent has used other psychoactive drugs in the past day. (Numeric)   ',
#  '| **0_14**                          | The respondent\\u0027s level of anxiety. (Numeric)                                                  ',
#  '| **0_15**                          | The respondent\\u0027s level of resilience. (Numeric)                                               ',
#  '| **0_16**                          | The respondent\\u0027s level of overall wellbeing. (Numeric)                                        ',
#  '| **0_17**                          | The respondent\\u0027s level of openness to experience. (Numeric)                                   ',
#  '| **0_18**                          | The respondent\\u0027s level of conscientiousness. (Numeric)                                        ',
#  '| **0_19**                          | The respondent\\u0027s level of extraversion. (Numeric)                                             ',
#  '| **0_20**                          | The respondent\\u0027s level of agreeableness. (Numeric)                                            ',
#  '| **0_41**                          | Number of times the respondent has used psychedelics in the past year. (Numeric)              ',
#  '| **0_42**                          | Number of times the respondent has used other psychoactive drugs in the past year. (Numeric)  ',
#  '| **0_43**                          | Number of times the respondent has used psychedelics in the past month. (Numeric)             ',
#  '| **0_44**                          | Number of times the respondent has used other psychoactive drugs in the past month. (Numeric) ',
#  '| **1_extraversion**                | The respondent\\u0027s level of extraversion. (Numeric)                                             ',
#  '| **1_agreeableness**               | The respondent\\u0027s level of agreeableness. (Numeric)                                            ',
#  '| **1_conscientiousness**           | The respondent\\u0027s level of conscientiousness. (Numeric)                                        ',
#  '| **1_neuroticism**                 | The respondent\\u0027s level of neuroticism. (Numeric)                                              ',
#  '| **1_openness**                    | The respondent\\u0027s level of openness to experience. (Numeric)                                   ',
#  '| **1_percentil_extraversion**      | The respondent\\u0027s percentile of extraversion. (Numeric)                                        ',
#  '| **1_percentil_agreeableness**     | The respondent\\u0027s percentile of agreeableness. (Numeric)                                       ',
#  '| **1_percentil_conscientiousness** | The respondent\\u0027s percentile of conscientiousness. (Numeric)                                   ',
#  '| **1_percentil_neuroticism**       | The respondent\\u0027s percentile of neuroticism. (Numeric)                                         ',
#  '| **1_percentil_openness**          | The respondent\\u0027s percentile of openness to experience. (Numeric)                              ',
#  '| **2_edad**                        | Age of the respondent. (Numeric)                                                              ',
#  '| **2_genero**                      | Gender of the respondent. (Categorical)                                                       ',
#  '| **2_pais_actual**                 | Country of residence of the respondent. (Categorical)                                         ',
#  '| **3_timestamp**                   | Timestamp of the survey response. (Numeric)                                                   ',
#  '| **hash**                          | Unique identifier for the respondent. (String)                                                ',
#  '| **0_21**                          | The respondent\\u0027s level of risk aversion. (Numeric)                                            ',
#  '| **0_22**                          | The respondent\\u0027s level of risk taking. (Numeric)                                              ',
#  '| **0_23**                          | The respondent\\u0027s level of impulsivity                                                         ']

# %% [markdown]
# Now that we've isolated the rows of the table we need to separate the two columns.

# %%
# Initialize the column lists
numbered_columns = []
descriptions = []

# Split each table line into two strings, the first goes into one column list and the second goes into the other
for line in kaggle_strings:
    split_line = line.split(" | ")
    numbered_columns.append(split_line[0])
    descriptions.append(split_line[1])
numbered_columns
# Out:
# ['| **0_1**                          ',
#  '| **0_2**                          ',
#  '| **0_3**                          ',
#  '| **0_4**                          ',
#  '| **0_5**                          ',
#  '| **0_6**                          ',
#  '| **0_7**                          ',
#  '| **0_8**                          ',
#  '| **0_9**                          ',
#  '| **0_10**                         ',
#  '| **0_11**                         ',
#  '| **0_12**                         ',
#  '| **0_13**                         ',
#  '| **0_14**                         ',
#  '| **0_15**                         ',
#  '| **0_16**                         ',
#  '| **0_17**                         ',
#  '| **0_18**                         ',
#  '| **0_19**                         ',
#  '| **0_20**                         ',
#  '| **0_41**                         ',
#  '| **0_42**                         ',
#  '| **0_43**                         ',
#  '| **0_44**                         ',
#  '| **1_extraversion**               ',
#  '| **1_agreeableness**              ',
#  '| **1_conscientiousness**          ',
#  '| **1_neuroticism**                ',
#  '| **1_openness**                   ',
#  '| **1_percentil_extraversion**     ',
#  '| **1_percentil_agreeableness**    ',
#  '| **1_percentil_conscientiousness**',
#  '| **1_percentil_neuroticism**      ',
#  '| **1_percentil_openness**         ',
#  '| **2_edad**                       ',
#  '| **2_genero**                     ',
#  '| **2_pais_actual**                ',
#  '| **3_timestamp**                  ',
#  '| **hash**                         ',
#  '| **0_21**                         ',
#  '| **0_22**                         ',
#  '| **0_23**                         ']

# %%
descriptions
# Out:
# ['Age of the respondent. (Numeric)                                                              ',
#  'Gender of the respondent. (Categorical)                                                       ',
#  'Country of residence of the respondent. (Categorical)                                         ',
#  'Number of times the respondent has used psychedelics. (Numeric)                               ',
#  'Number of times the respondent has used other psychoactive drugs. (Numeric)                   ',
#  'Number of times the respondent has used psychedelics in the past year. (Numeric)              ',
#  'Number of times the respondent has used other psychoactive drugs in the past year. (Numeric)  ',
#  'Number of times the respondent has used psychedelics in the past month. (Numeric)             ',
#  'Number of times the respondent has used other psychoactive drugs in the past month. (Numeric) ',
#  'Number of times the respondent has used psychedelics in the past week. (Numeric)              ',
#  'Number of times the respondent has used other psychoactive drugs in the past week. (Numeric)  ',
#  'Number of times the respondent has used psychedelics in the past day. (Numeric)               ',
#  'Number of times the respondent has used other psychoactive drugs in the past day. (Numeric)   ',
#  'The respondent\\u0027s level of anxiety. (Numeric)                                                  ',
#  'The respondent\\u0027s level of resilience. (Numeric)                                               ',
#  'The respondent\\u0027s level of overall wellbeing. (Numeric)                                        ',
#  'The respondent\\u0027s level of openness to experience. (Numeric)                                   ',
#  'The respondent\\u0027s level of conscientiousness. (Numeric)                                        ',
#  'The respondent\\u0027s level of extraversion. (Numeric)                                             ',
#  'The respondent\\u0027s level of agreeableness. (Numeric)                                            ',
#  'Number of times the respondent has used psychedelics in the past year. (Numeric)              ',
#  'Number of times the respondent has used other psychoactive drugs in the past year. (Numeric)  ',
#  'Number of times the respondent has used psychedelics in the past month. (Numeric)             ',
#  'Number of times the respondent has used other psychoactive drugs in the past month. (Numeric) ',
#  'The respondent\\u0027s level of extraversion. (Numeric)                                             ',
#  'The respondent\\u0027s level of agreeableness. (Numeric)                                            ',
#  'The respondent\\u0027s level of conscientiousness. (Numeric)                                        ',
#  'The respondent\\u0027s level of neuroticism. (Numeric)                                              ',
#  'The respondent\\u0027s level of openness to experience. (Numeric)                                   ',
#  'The respondent\\u0027s percentile of extraversion. (Numeric)                                        ',
#  'The respondent\\u0027s percentile of agreeableness. (Numeric)                                       ',
#  'The respondent\\u0027s percentile of conscientiousness. (Numeric)                                   ',
#  'The respondent\\u0027s percentile of neuroticism. (Numeric)                                         ',
#  'The respondent\\u0027s percentile of openness to experience. (Numeric)                              ',
#  'Age of the respondent. (Numeric)                                                              ',
#  'Gender of the respondent. (Categorical)                                                       ',
#  'Country of residence of the respondent. (Categorical)                                         ',
#  'Timestamp of the survey response. (Numeric)                                                   ',
#  'Unique identifier for the respondent. (String)                                                ',
#  'The respondent\\u0027s level of risk aversion. (Numeric)                                            ',
#  'The respondent\\u0027s level of risk taking. (Numeric)                                              ',
#  'The respondent\\u0027s level of impulsivity                                                         ']

# %% [markdown]
# Next we need to modify `numbered_columns` so that the column names match those in the data frame.

# %%
# Rename the entries in numbered_columns
for entry in numbered_columns:
    entry_index = numbered_columns.index(entry)
    split_entry = entry.split("**")
    entry = split_entry[1]
    numbered_columns[entry_index] = entry
numbered_columns
# Out:
# ['0_1',
#  '0_2',
#  '0_3',
#  '0_4',
#  '0_5',
#  '0_6',
#  '0_7',
#  '0_8',
#  '0_9',
#  '0_10',
#  '0_11',
#  '0_12',
#  '0_13',
#  '0_14',
#  '0_15',
#  '0_16',
#  '0_17',
#  '0_18',
#  '0_19',
#  '0_20',
#  '0_41',
#  '0_42',
#  '0_43',
#  '0_44',
#  '1_extraversion',
#  '1_agreeableness',
#  '1_conscientiousness',
#  '1_neuroticism',
#  '1_openness',
#  '1_percentil_extraversion',
#  '1_percentil_agreeableness',
#  '1_percentil_conscientiousness',
#  '1_percentil_neuroticism',
#  '1_percentil_openness',
#  '2_edad',
#  '2_genero',
#  '2_pais_actual',
#  '3_timestamp',
#  'hash',
#  '0_21',
#  '0_22',
#  '0_23']

# %% [markdown]
# Now make a loop that will change the column names in `master_data`.

# %%
# Change the names of the columns in master_data
for entry in numbered_columns:
    if entry in master_data.columns.values.tolist():
        entry_index = numbered_columns.index(entry)
        master_data.rename(columns={entry:descriptions[entry_index]},
                          inplace=True) # inplace=True is needed to ensure the column name gets changed in the data frame
master_data.columns.values.tolist()
# Out:
# ['Age of the respondent. (Numeric)                                                              ',
#  'Gender of the respondent. (Categorical)                                                       ',
#  'Country of residence of the respondent. (Categorical)                                         ',
#  'Number of times the respondent has used psychedelics. (Numeric)                               ',
#  'Number of times the respondent has used other psychoactive drugs. (Numeric)                   ',
#  'Number of times the respondent has used psychedelics in the past year. (Numeric)              ',
#  'Number of times the respondent has used other psychoactive drugs in the past year. (Numeric)  ',
#  'Number of times the respondent has used psychedelics in the past month. (Numeric)             ',
#  'Number of times the respondent has used other psychoactive drugs in the past month. (Numeric) ',
#  'Number of times the respondent has used psychedelics in the past week. (Numeric)              ',
#  'Number of times the respondent has used other psychoactive drugs in the past week. (Numeric)  ',
#  'Number of times the respondent has used psychedelics in the past day. (Numeric)               ',
#  'Number of times the respondent has used other psychoactive drugs in the past day. (Numeric)   ',
#  'The respondent\\u0027s level of anxiety. (Numeric)                                                  ',
#  'The respondent\\u0027s level of resilience. (Numeric)                                               ',
#  'The respondent\\u0027s level of overall wellbeing. (Numeric)                                        ',
#  'The respondent\\u0027s level of openness to experience. (Numeric)                                   ',
#  'The respondent\\u0027s level of conscientiousness. (Numeric)                                        ',
#  'The respondent\\u0027s level of extraversion. (Numeric)                                             ',
#  'The respondent\\u0027s level of agreeableness. (Numeric)                                            ',
#  'The respondent\\u0027s level of risk aversion. (Numeric)                                            ',
#  'The respondent\\u0027s level of risk taking. (Numeric)                                              ',
#  'The respondent\\u0027s level of impulsivity                                                         ',
#  '0_24',
#  '0_25',
#  '0_26',
#  '0_27',
#  '0_28',
#  '0_29',
#  '0_30',
#  '0_31',
#  '0_32',
#  '0_33',
#  '0_34',
#  '0_35',
#  '0_36',
#  '0_37',
#  '0_38',
#  '0_39',
#  '0_40',
#  'Number of times the respondent has used psychedelics in the past year. (Numeric)              ',
#  'Number of times the respondent has used other psychoactive drugs in the past year. (Numeric)  ',
#  'Number of times the respondent has used psychedelics in the past month. (Numeric)             ',
#  'Number of times the respondent has used other psychoactive drugs in the past month. (Numeric) ',
#  'The respondent\\u0027s level of extraversion. (Numeric)                                             ',
#  'The respondent\\u0027s level of agreeableness. (Numeric)                                            ',
#  'The respondent\\u0027s level of conscientiousness. (Numeric)                                        ',
#  'The respondent\\u0027s level of neuroticism. (Numeric)                                              ',
#  'The respondent\\u0027s level of openness to experience. (Numeric)                                   ',
#  'The respondent\\u0027s percentile of extraversion. (Numeric)                                        ',
#  'The respondent\\u0027s percentile of agreeableness. (Numeric)                                       ',
#  'The respondent\\u0027s percentile of conscientiousness. (Numeric)                                   ',
#  'The respondent\\u0027s percentile of neuroticism. (Numeric)                                         ',
#  'The respondent\\u0027s percentile of openness to experience. (Numeric)                              ',
#  'Age of the respondent. (Numeric)                                                              ',
#  'Gender of the respondent. (Categorical)                                                       ',
#  '2_nacionalidad',
#  'Country of residence of the respondent. (Categorical)                                         ',
#  'Timestamp of the survey response. (Numeric)                                                   ',
#  'Unique identifier for the respondent. (String)                                                ',
#  '0_religiosidad',
#  '0_frecuencia_practicas_religiosas',
#  '0_cambio_frecuencia_practicas_religiosas',
#  '0_frecuencia_meditacion',
#  '0_cambio_frecuencia_meditacion',
#  '0_antencion_previa',
#  '0_internacion',
#  '0_tomando_medicacion',
#  '1_psicodelicos_consumidos',
#  '2_cuantas_veces_consumio',
#  '2_calificacion_experiencia',
#  '2_programa_microdosificacion',
#  '2_cambio_consumo',
#  '2_disminuyo_por_factores',
#  '3_psicodelico_mas_significativo',
#  '4_psicodelico_ultima_vez',
#  '5_psicodelicos_motivos',
#  '5_otro_motivo',
#  '6_psicoactivos_cosumidos',
#  '6_otro_psicoactivo',
#  '7_marihuana',
#  '7_estimulantes',
#  '7_sedativos',
#  '7_antidepresivos o antipsicoticos',
#  '7_disociativos',
#  '7_mdma',
#  '7_otro',
#  '7_marihuana_disminuyo_por_factores_externos',
#  '7_estimulantes_disminuyo_por_factores_externos',
#  '7_sedativos_disminuyo_por_factores_externos',
#  '7_antidepresivos o antipsicoticos_disminuyo_por_factores_externos',
#  '7_disociativos_disminuyo_por_factores_externos',
#  '7_mdma_disminuyo_por_factores_externos',
#  '7_otro_disminuyo_por_factores_externos',
#  '7_tabaco',
#  '7_tabaco_disminuyo_por_factores_externos',
#  '7_cafeína',
#  '7_cafeína_disminuyo_por_factores_externos',
#  '7_alcohol',
#  '7_alcohol_disminuyo_por_factores_externos',
#  '8_calmado',
#  '8_seguro',
#  '8_tenso',
#  '8_disgustado',
#  '8_como_pez_en_el_agua',
#  '8_alterado',
#  '8_preocupado_posible_problema',
#  '8_satisfecho',
#  '8_asustado',
#  '8_comodo',
#  '8_confiado',
#  '8_nervioso',
#  '8_agitado',
#  '8_indeciso',
#  '8_tranquilo',
#  '8_a_gusto',
#  '8_preocupado',
#  '8_aturdido',
#  '8_equilibrado',
#  '8_bien',
#  '9_bien',
#  '9_nervioso',
#  '9_a_gusto',
#  '9_quisiera_ser_tan_feliz',
#  '9_siento_que_fallo',
#  '9_descansado',
#  '9_tranquila_serena_calmada',
#  '9_dificultades_se_amontonan',
#  '9_preocupo_por_cosas_sin_importancia',
#  '9_feliz',
#  '9_malos_pensamientos',
#  '9_falta_confianza',
#  '9_seguro',
#  '9_decidirme_rapidamente',
#  '9_fuera_de_lugar',
#  '9_satisfecho',
#  '9_cosas_poco_importantes_ocupan_molestan',
#  '9_desengaños_afectan',
#  '9_persona_estable',
#  '9_cosas_entre_manos_nervioso_tenso',
#  '10_interesado',
#  '10_angustiado',
#  '10_ilusionado_emocionado',
#  '10_afectado',
#  '10_fuerte',
#  '10_culpable',
#  '10_asustado',
#  '10_agresivo',
#  '10_entusiasmado',
#  '10_satisfecho_consigo_mismo',
#  '10_irritable',
#  '10_despierto',
#  '10_avergonzado',
#  '10_inspirado',
#  '10_nervioso',
#  '10_decidido',
#  '10_concentrado',
#  '10_agitado',
#  '10_activo',
#  '10_miedoso',
#  '11_se_lo_que_quiero_hacer',
#  '11_aceptar_lo_que_sale_mal',
#  '11_importa_pensar_en_futuro',
#  '11_puedo_decir_lo_que_pienso',
#  '11_le_caigo_bien_a_la_gente',
#  '11_podre_lograr_metas',
#  '11_cuento_con_personas_que_ayudan',
#  '11_en_general_me_llevo_bien_con_la_gente',
#  '11_hago_lo_que_quiero',
#  '11_capaz_de_pensar_proyecto_de_vida',
#  '11_aceptar_equivocaciones_mejorar',
#  '11_tomar_decisiones_sin_dudar',
#  '11_encaro_oblicaciones_sin_problemas',
#  '12_llevo_a_cabo_planes_hasta_el_final',
#  '12_manejo_problemas_distintos_modos',
#  '12_hacer_cosas_sin_depender',
#  '12_mantengo_interes_cosas_importantes',
#  '12_tomar_las_cosas_sin_preocupacion',
#  '12_amigable_conmigo',
#  '12_manejar_varias_cosas',
#  '12_decidido',
#  '12_rara_vez_pregunto_objetivo_de_las_cosas',
#  '12_hago_cosas_de_a_una',
#  '12_auto_disciplinado',
#  '12_mantengo_interes',
#  '12_usualmente_encuentro_cosas_de_que_reirme',
#  '12_confianza_en_mi_pasar_tiempos_dificiles',
#  '12_en_emergencias_pueden_confiar_en_mi',
#  '12_ver_situacion_varios_puntos_de_vista',
#  '12_mi_vida_tiene_sentido',
#  '12_no_insito_en_cosas_que_no_puedo_hacer_nada',
#  '12_encuentro_salida_en_situacion_dificil',
#  '12_tengo_energia_para_lo_que_tengo_que_hacer',
#  '12_siento_comodo_si_hay_gente_a_la_que_no_le_agrado',
#  '13_login_disclaimer_fork']

# %% [markdown]
# Finally, save `master_data` as a `.csv` so we can load it in the next notebook, [CleaningII](CleaningII.ipynb).

# %%
# Save master_data to a csv file
master_data.to_csv("data/master_data.csv")
