# %% [markdown]
# # Data cleaning and preprocessing
#
# Since we gathered the data ourselves, the data is pretty clean.  However there is a lot of preprocessing to do.  First we recreate the data frame from [ProblemStatement](ProblemStatement.ipynb), this time adding titles to the columns.

# %%
# Import pandas to make the data frame
import pandas as pd

# Rereate the data frame using the output file from ProblemStatement
# Render the data frame
raw_data = pd.read_csv("ProblemStatementOutputs/50_25-03-2023_17-09-02.csv")
# Add headers to the columns
raw_data.columns = ["Post type", "Title", "Post url", "Author(s)", "Date and time posted", "Tags", "No. of comments"]
# Show the data frame
raw_data
# Out:
#    Post type                                              Title  \
# 0    article  Unions Have Been Under Attack For Decades, But...
# 1    article      Which Taylor Swift Album Is The Most Popular?
# 2    podcast           Will Voters Care If Trump Gets Indicted?
# 3    podcast  Politics Podcast: The Manhattan DA Might Be Th...
# 4      video       Why Is Biden Moving To The Political Center?
# 5    article  Recess Is Good For Kids. Why Don’t More States...
# 6    article          What We Know About Trump’s Legal Troubles
# 7    article                 What Happens If Trump Is Indicted?
# 8    article  States Are Cracking Down On Militias — Except ...
# 9    podcast                          Bank Bailout Politics 2.0
# 10   podcast  20 Years After The Iraq Invasion, Are American...
# 11   podcast  Politics Podcast: The 2000s Called, They Want ...
# 12   article  20 Years After The Invasion Of Iraq, Americans...
# 13   article  It’s Not Just Silicon Valley Bank — Americans ...
# 14   podcast             The Hidden Stories In The U.S. Census
# 15   article  How Did State Supreme Court Races Get So Expen...
# 16   article  Democratic Dads Think It’s Gotten Easier To Ra...
# 17   article  Ron DeSantis Is Doubling Down On His Education...
# 18     video  Republican Politicians Are Struggling To Defin...
# 19   article  Republicans Lawmakers Are Trying To Ban Drag. ...
# 20   article  What Does the Silicon Valley Bank Collapse Mea...
# 21   podcast              Where The Debate Over Abortion Stands
# 22   podcast  Polls Haven’t Been This Accurate Since At Leas...
# 23   podcast  Politics Podcast: This Is The Best Pollster In...
# 24   article     There’s A Racial Bias on Police Facebook Pages
# 25   article          Red States Are Fighting Their Blue Cities
# 26     video  The Polls Got It Right In 2022. Here Are The P...
# 27   article       The Polls Were Historically Accurate In 2022
# 28   article  Americans Want Tighter Railroad Regulations Af...
# 29   article                      How Our Pollster Ratings Work
# 30   podcast  What Would Happen If Trump Was A Third-Party C...
# 31   podcast  Politics Podcast: Few Americans Think AI Will ...
# 32   article  Some GOP Legislators Are Trying To Show They’r...
# 33     video  Why Is 2 Percent The Federal Reserve’s Magic N...
# 34   article   The Fed’s Inflation Goal Is Completely Arbitrary
# 35   article                     Does CPAC Even Matter Anymore?
# 36   article  How Asian Americans Came To Play A Central Rol...
# 37   article           Does It Matter Where COVID-19 Came From?
# 38   article  The House Is About To Have 435 Members. That’s...
# 39   podcast   Why Lori Lightfoot Lost The Chicago Mayor’s Race
# 40   podcast                        The Poll That Ended Dilbert
# 20  Slack Chat; Bailout; Recession; Great Recessio...               11
# 21  Politics Podcast; Video; 2022 Midterms; Aborti...                5
# 22    Politics Podcast; Video; Polling; 2022 Midterms                5
# 23  FiveThirtyEight Podcasts; Politics Podcast; Po...                5
# 24  Race; Crime; Facebook; Racism; Police; Crime Data                4
# 25  Partisanship; Cities; Rural; Urban; Red States...               10
# 26  Video; Polling; Polls; 2022 Election; Featured...                5
# 27  Polling; Polls; 2022 Election; Generic Ballot;...               15
# 28  Joe Biden; Polls; COVID-19; Pollapalooza; Pete...                5
# 29                           Methodology; Methodology                4
# 30  Donald Trump; Politics Podcast; Video; 2024 El...                6
# 31  FiveThirtyEight Podcasts; Politics Podcast; Po...                7
# 32  Abortion; Access To Abortion; Medicaid; Red St...                8
# 33  Video; Featured video; Economy; Inflation; Fed...                8
# 34  Economy; Inflation; Federal Reserve; Interest ...                7
# 35  Donald Trump; Republican Party; Conservatives;...               14
# 36  Supreme Court; College; Affirmative Action; As...               10
# 37                       COVID-19; Coronavirus; China               17
# 38  Congress; House of Representatives; Scandals; ...                3
# 39  Politics Podcast; Video; Virginia; Wisconsin; ...                7
# 40           Politics Podcast; Video; Polling; Racism                6
# 41  Politics Podcast; Video; Joe Biden; Marianne W...                5
# 42  FiveThirtyEight Podcasts; Politics Podcast; Po...                3
# 43  Donald Trump; Favorability Ratings; Mike Pence...               12
# 44  Labor Force; Paid Leave; Productivity; 4 Day W...                8
# 45  Joe Biden; Supreme Court; Pollapalooza; Studen...               12
# 46  Politics Podcast; Video; Economy; Inflation; F...                5
# 47  FiveThirtyEight Podcasts; Politics Podcast; Ec...                4
# 48  Joe Biden; Polling; Polls; Approval Ratings; F...               23
# 49   Slack Chat; 2024 Election; 2024 Senate Elections               10

# %% [markdown]
# Now we get the total number of comments per tag, and the average number of comments per post for each tag.

# %%
# Input is one of the column titles from the raw_data data frame, as a string.
# Needs the raw_data data frame
# Output is a data frame containing the frequency, total number of comments, and average number of comments.
def comments_analysis(attribute):
    #print("Data for "+attribute+":") # for debugging
    all_attr_with_repeats = []
    for feature_attr in raw_data[attribute]:
        with_commas = feature_attr.split("; ")
        for attr in with_commas:
            all_attr_with_repeats.append(attr) 
    all_attr_list = [*set(all_attr_with_repeats)]
    #print("Possible values:\n", all_attr_list) # for debugging
    attr_frequency_list = []
    attr_total_comments_list = []
    attr_avg_no_of_comments_list = []
    for i in range(len(all_attr_list)):
        #print("Iteration "+str(i)+".  Attribute is "+all_attr_list[i]+".") # for debugging
        #print("Here is the nested loop.") # for debugging
        occurences = 0
        comments = 0
        for index, row in raw_data.iterrows():
            #print("The index is "+str(index)+".") # for debugging
            attr_in_row_list = str(row[attribute]).split("; ")
            #print("The attrs are:\n"+str(attr_in_row_list)+".") # for debugging
            #print("The Boolean value of the if statement is "+ str(all_attr_list[i] in attr_in_row_list)+".") # for debugging
            if all_attr_list[i] in attr_in_row_list:
                #print("Before occurences = "+str(occurences)+ " and comments = "+ str(comments)+".") # for debugging
                occurences = occurences +1
                comments = comments + int(row["No. of comments"])
                #print("Now occurences = "+str(occurences)+ " and comments = "+ str(comments)+".") # for debugging
        #print("Exiting the nested loop.") # for debugging
        #print("Results:  occurences = "+str(occurences)+" and comments = "+str(comments)+".") # for debugging
        attr_frequency_list.append(occurences)
        attr_total_comments_list.append(comments) 
        avg = int(attr_total_comments_list[i])/int(attr_frequency_list[i])
        #print("Finally, avg = "+str(avg)+".\n") # for debugging
        attr_avg_no_of_comments_list.append(avg)
    attr_info_dict = {
        attribute:all_attr_list, 
        "Frequency":attr_frequency_list, 
        "Total no. of comments":attr_total_comments_list,
        "Avg no. of comments":attr_avg_no_of_comments_list
    }    
    return pd.DataFrame(attr_info_dict, columns = [attribute, "Frequency", "Total no. of comments", "Avg no. of comments"])

# %%
# Try the function
authors_info = comments_analysis("Author(s)")
authors_info
# Out:
#                  Author(s)  Frequency  Total no. of comments  \
# 0   Amelia Thomson-DeVeaux         13                     97
# 1         Nathaniel Rakich         18                    156
# 2             Alex Samuels          4                     48
# 3         Geoffrey Skelley          7                     61
# 4              Galen Druke         17                     94
# 5           Kaleigh Rogers          6                     69
# 6               Julian Kim          1                     15
# 7             Monica Potts          8                     66
# 8            Maggie Koerth          2                     21
# 9              Nate Silver         11                     58
# 10           Cooper Burton          1                      5
# 11           Santul Nerkar          5                     36
# 12         Anna Rothschild          1                      8
# 13               Tony Chow          2                     20
#
#     Avg no. of comments
# 0              7.461538
# 1              8.666667
# 2             12.000000
# 3              8.714286
# 4              5.529412
# 5             11.500000
# 6             15.000000
# 7              8.250000
# 8             10.500000
# 9              5.272727
# 10             5.000000
# 11             7.200000
# 12             8.000000
# 13            10.000000

# %%
# Try the function
tags_info = comments_analysis("Tags")
tags_info
# Out:
#                         Tags  Frequency  Total no. of comments  \
# 0                   Militias          1                     10
# 1        Marianne WIlliamson          3                     31
# 2                   Facebook          1                      4
# 3                 Federalism          1                     10
# 4    2024 Democratic Primary          2                     28
# ..                       ...        ...                    ...
# 134                     Iraq          1                      4
# 135                  College          1                     10
# 136         Campaign Finance          1                      6
# 137                Extremism          1                      8
# 138                     Drag          2                     23
#
#      Avg no. of comments
# 0              10.000000
# 1              10.333333
# 2               4.000000
# 3              10.000000
# 4              14.000000
# ..                   ...
# 134             4.000000
# 135            10.000000
# 136             6.000000
# 137             8.000000
# 138            11.500000
#
# [139 rows x 4 columns]

# %%
# Try the function
post_type_info = comments_analysis("Post type")
post_type_info
# Out:
#   Post type  Frequency  Total no. of comments  Avg no. of comments
# 0   article         29                    285             9.827586
# 1     video          4                     43            10.750000
# 2   podcast         17                     94             5.529412
